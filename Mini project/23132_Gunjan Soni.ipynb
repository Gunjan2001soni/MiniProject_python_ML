# %% [markdown]
# # TASK 1 - Exploratory Data Analysis

# %% [markdown]
# Question 1 . Are there any missing values in Zomato dataset?

# %%
import numpy as np
import pandas as pd

# %%
z=pd.read_csv('zomato.csv')

# %%
z
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
z.shape
# Out:
# (51717, 17)

# %%
z.isnull()
# Out:
#          url  address   name  online_order  book_table   rate  votes  phone  \
# 0      False    False  False         False       False  False  False  False
# 1      False    False  False         False       False  False  False  False
# 2      False    False  False         False       False  False  False  False
# 3      False    False  False         False       False  False  False  False
# 4      False    False  False         False       False  False  False  False
# ...      ...      ...    ...           ...         ...    ...    ...    ...
# 51712  False    False  False         False       False  False  False  False
# 51713  False    False  False         False       False   True  False  False
# 51714  False    False  False         False       False   True  False   True
# 51715  False    False  False         False       False  False  False  False
# 51716  False    False  False         False       False  False  False  False
#
# ...

# %%
z.isna().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %% [markdown]
# Question 2.Delete redundant columns like url,phone and address.

# %%
z=z.drop(['url','address','phone'],axis=1)

# %%
z
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                    location  \
# 0            Yes   4.1/5    775                Banashankari
# ...

# %% [markdown]
# Question 3.Replace null values in the dataset with N/A.

# %%
z=z.fillna(value='N/A')

# %%
z.isna().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# location                       0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %% [markdown]
# Question 4. Plot a bar graph of restaurants that deliver food online or offline

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
z['online_order'].value_counts()
# Out:
# online_order
# Yes    30444
# No     21273
# Name: count, dtype: int64

# %%
x=['Yes','No']
y=[30444,21273]

# %%
xpos=np.arange(len(x))
xpos
# Out:
# array([0, 1])

# %%
plt.xticks(xpos,x)
plt.bar(xpos,y,color='pink')
plt.xlabel('Online Orders')
plt.ylabel('no. of restraunts')
# Out:
# Text(0, 0.5, 'no. of restraunts')

# %% [markdown]
# Question 5.Plot a bar graph comparing 'Table booking Rate vs Rating'

# %%
z.dtypes
# Out:
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %%
z['rate']
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 51712    3.6 /5
# 51713       N/A
# 51714       N/A
# 51715    4.3 /5
# 51716    3.4 /5
# Name: rate, Length: 51717, dtype: object

# %%
z['rate']=z['rate'].str.extract('(\d+\.\d+)').astype(float)

# %%
z['rate']
# Out:
# 0        4.1
# 1        4.1
# 2        3.8
# 3        3.7
# 4        3.8
#         ...
# 51712    3.6
# 51713    NaN
# 51714    NaN
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 51717, dtype: float64

# %%
binary_mapping={"Yes":1,"No": 0}
z['table_booking']=z['book_table'].map(binary_mapping)

# %%
z['table_booking']
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 51712    0
# 51713    0
# 51714    0
# 51715    1
# 51716    0
# Name: table_booking, Length: 51717, dtype: int64

# %%
plt.scatter(z['table_booking'],z['rate'],color='pink')

# %% [markdown]
# # TASK-2 Classification / Regression

# %% [markdown]
# Perform following steps on the same dataset which you used for EDA.
#
# Data Preprocessing (as per requirement),
#
# Feature Engineering,
#
# Split dataset in train-test (80:20 ratio),
#
# Model selection,
#
# Model training,
#
# Model evaluation,
#
# Fine-tune the Model,
#
# Make predictions,
#
# Summarize your model's performance by evaluation metrices

# %%
z
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table  rate  votes                    location  \
# 0            Yes   4.1    775                Banashankari
# ...

# %%
# Dropping Url and Phone no as they are useless for this project. 
#There is a bit of confusion between location and listed_in(city) are very similar, listed_in(city) indicates
#that a specific restaurant privdes its services there, while other location indicates which city the restuarant
#adddress is located exactly, so I will drop location
#No useful info can be extracted directly from the url, address, name and menu_item so I will drop them
z.drop(['dish_liked','location','menu_item','name'], axis =1, inplace=True)

# %%
z
# Out:
#       online_order book_table  rate  votes            rest_type  \
# 0              Yes        Yes   4.1    775        Casual Dining
# 1              Yes         No   4.1    787        Casual Dining
# 2              Yes         No   3.8    918  Cafe, Casual Dining
# 3               No         No   3.7     88          Quick Bites
# 4               No         No   3.8    166        Casual Dining
# ...            ...        ...   ...    ...                  ...
# 51712           No         No   3.6     27                  Bar
# 51713           No         No   NaN      0                  Bar
# 51714           No         No   NaN      0                  Bar
# 51715           No        Yes   4.3    236                  Bar
# 51716           No         No   3.4     13   Bar, Casual Dining
#
#                                      cuisines approx_cost(for two people)  \
# 0              North Indian, Mughlai, Chinese                         800
# ...

# %%
# Dropping duplicates.
print('Number of Dublicate values in Data Frame = ',z.duplicated().sum())
z.drop_duplicates(inplace=True)
# Out:
# Number of Dublicate values in Data Frame =  508

# %%
# Remove the NaN values from the dataset
z.dropna(how='any',inplace=True)

# %%
z.reset_index(inplace = True, drop = True)

# %%
z
# Out:
#       online_order book_table  rate  votes            rest_type  \
# 0              Yes        Yes   4.1  775.0        Casual Dining
# 1              Yes         No   4.1  787.0        Casual Dining
# 2              Yes         No   3.8  918.0  Cafe, Casual Dining
# 3               No         No   3.7   88.0          Quick Bites
# 4               No         No   3.8  166.0        Casual Dining
# ...            ...        ...   ...    ...                  ...
# 41615           No         No   3.7   34.0   Casual Dining, Bar
# 41616           No         No   2.5   81.0   Casual Dining, Bar
# 41617           No         No   3.6   27.0                  Bar
# 41618           No        Yes   4.3  236.0                  Bar
# 41619           No         No   3.4   13.0   Bar, Casual Dining
#
#                                           cuisines  \
# 0                   North Indian, Mughlai, Chinese
# 1                      Chinese, North Indian, Thai
# ...

# %%
z['votes']=z['votes'].astype(float)

# %%
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41620 entries, 0 to 51716
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   online_order                 41620 non-null  object
#  1   book_table                   41620 non-null  object
#  2   rate                         41620 non-null  float64
#  3   votes                        41620 non-null  float64
#  4   rest_type                    41620 non-null  object
#  5   cuisines                     41620 non-null  object
#  6   approx_cost(for two people)  41620 non-null  object
#  7   reviews_list                 41620 non-null  object
#  8   listed_in(type)              41620 non-null  object
#  9   listed_in(city)              41620 non-null  object
#  10  table_booking                41620 non-null  int64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 3.8+ MB

# %%
z.drop(['reviews_list'],axis=1,inplace=True)
